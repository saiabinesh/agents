# %% [markdown]
# # Agentic AI — Daily Recall Notebook
# ## Week 1 · Day 1 · Date: YYYY-MM-DD
#
# Focus:
# - Labs → Concepts → Exercises

# %% [markdown]
# ## Lab — Recall (from memory)
#
# Shortcuts
# for notetaking
#
# • Core paradigm touched:
# • What felt non-obvious:
# • One thing I could not explain yet:

# %%
# Lab / Exercise code
# Do not explain here

# %%
print("a+b")
